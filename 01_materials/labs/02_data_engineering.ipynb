# %%
# %load_ext dotenv
# %dotenv
# Out:
# The dotenv extension is already loaded. To reload it, use:
#   %reload_ext dotenv

# %% [markdown]
# # What are we doing?
#
# ## Objectives
#
#
# * Build a data pipeline that downloads price data from the internet, stores it locally, transforms it into return data, and stores the feature set.
#     - Getting the data.
#     - Schemas and index in dask.
#
# * Explore the parquet format.
#     - Reading and writing parquet files.
#     - Read datasets that are stored in distributed files.
#     - Discuss dask vs pandas as a small example of big vs small data.
#
# * Discuss the use of environment variables for settings.
# * Discuss how to use Jupyter notebooks and source code concurrently.
# * Logging and using a standard logger.
#
# ## About the Data
#
# + We will download the prices for a list of stocks.
# + The source is Yahoo Finance and we will use the API provided by the library yfinance.
#
#
# ## Medallion Architecture
#
# + The architecture that we are thinking about is called Medallion by [DataBricks](https://www.databricks.com/glossary/medallion-architecture). It is an ELT type of thinking, although our data is well-structured.
#
# ![Medallion Architecture (DataBicks)](./images/02_medallion_architecture.png)
#
# + In our case, we would like to optimize the number of times that we download data from the internet.
# + Ultimately, we will build a pipeline manager class that will help us control the process of obtaining and transforming our data.
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# # Download Data from Yahoo Finance
#
# Yahoo Finance provides information about public stocks in different markets. The library yfinance gives us access to a fair bit of the data in Yahoo Finance.
#
# These steps are based on the instructions in:
#
# + [yfinance documentation](https://pypi.org/project/yfinance/)
# + [Tutorial in geeksforgeeks.org](https://www.geeksforgeeks.org/get-financial-data-from-yahoo-finance-with-python/)

# %% [markdown]
# + If required, install: `python -m pip install yfinance`.
# + To download the price history of a stock, first use the following setup:

# %%
import pandas as pd
import yfinance as yf
import os
import sys

sys.path.append(os.getenv('SRC_DIR'))

# %% [markdown]
# A few things to notice in the code chunk above:
#
# + Libraries are ordered from high-level to low-level libraries from the package manager (pip in this case, but could be conda, poetry, etc.)
# + The command `sys.path.append("../05_src/)` will add the `../05_src/` directory to the path in the Notebook's kernel. This way, we can use our modules as part of the notebook.
# + Local modules are imported at the end.
# + The function `get_logger()` is called with `__name__` as recommended by the documentation.

# %% [markdown]
# Now, to download the historical price data for a stock, we could use:

# %%
px = yf.download('AAPL', start = "2013-12-01", end = "2024-02-01")
px
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close       Close        High         Low  \
# Ticker                           AAPL        AAPL        AAPL        AAPL
# Date
# 2013-12-02 00:00:00+00:00   17.175100   19.686787   20.154642   19.672144
# 2013-12-03 00:00:00+00:00   17.645264   20.225714   20.227858   19.917143
# 2013-12-04 00:00:00+00:00   17.604139   20.178572   20.328215   20.029285
# 2013-12-05 00:00:00+00:00   17.694500   20.282143   20.540714   20.228930
# 2013-12-06 00:00:00+00:00   17.448971   20.000713   20.241072   19.984644
# ...                               ...         ...         ...         ...
# 2024-01-25 00:00:00+00:00  193.223389  194.169998  196.270004  193.110001
# 2024-01-26 00:00:00+00:00  191.481903  192.419998  194.759995  191.940002
# 2024-01-29 00:00:00+00:00  190.795288  191.729996  192.199997  189.580002
# 2024-01-30 00:00:00+00:00  187.123260  188.039993  191.800003  187.470001
# 2024-01-31 00:00:00+00:00  183.501022  184.399994  187.100006  184.350006
#
# Price                            Open     Volume
# Ticker                           AAPL       AAPL
# Date
# 2013-12-02 00:00:00+00:00   19.928572  472544800
# 2013-12-03 00:00:00+00:00   19.939285  450968000
# 2013-12-04 00:00:00+00:00   20.196428  377809600
# 2013-12-05 00:00:00+00:00   20.451786  447580000
# 2013-12-06 00:00:00+00:00   20.206785  344352400
# ...                               ...        ...
# 2024-01-25 00:00:00+00:00  195.220001   54822100
# 2024-01-26 00:00:00+00:00  194.270004   44594000
# 2024-01-29 00:00:00+00:00  192.009995   47145600
# 2024-01-30 00:00:00+00:00  190.940002   55859400
# 2024-01-31 00:00:00+00:00  187.039993   55467800
#
# [2558 rows x 6 columns]

# %% [markdown]
# ## Parametrize the download
#
# + Generally, we will look to separate every parameter and setting from functions.
# + If we had a few stocks, we could cycle through them. We need a place to store the list of tickers (a db or file, for example).
# + Store a csv file with a few stock tickers. The location of the file is a setting, the contents of this file are parameters.
# + Use **environment variables** to pass parameters.
#
# Start by getting a sample of Information Technology stock tickers by applying subindexing and converting the "ticker" column from a pandas object to a list.

# %%
# Load all tickers
ticker_file = os.getenv("TICKERS")
tickers = pd.read_csv(ticker_file)
tickers
# Out:
#     ticker              Security             GICS Sector  \
# 0      MMM                    3M             Industrials
# 1      AOS           A. O. Smith             Industrials
# 2      ABT                Abbott             Health Care
# 3     ABBV                AbbVie             Health Care
# 4      ACN             Accenture  Information Technology
# ..     ...                   ...                     ...
# 498    YUM           Yum! Brands  Consumer Discretionary
# 499   ZBRA    Zebra Technologies  Information Technology
# 500    ZBH         Zimmer Biomet             Health Care
# 501   ZION  Zions Bancorporation              Financials
# 502    ZTS                Zoetis             Health Care
#
#                       GICS Sub-Industry    Headquarters Location  Date added  \
# 0              Industrial Conglomerates    Saint Paul, Minnesota       20883
# 1                     Building Products     Milwaukee, Wisconsin       42942
# 2                 Health Care Equipment  North Chicago, Illinois       20883
# 3                         Biotechnology  North Chicago, Illinois       41274
# 4        IT Consulting & Other Services          Dublin, Ireland       40730
# ..                                  ...                      ...         ...
# 498                         Restaurants     Louisville, Kentucky       35709
# 499  Electronic Equipment & Instruments   Lincolnshire, Illinois       43822
# 500               Health Care Equipment          Warsaw, Indiana       37110
# 501                      Regional Banks     Salt Lake City, Utah       37064
# 502                     Pharmaceuticals   Parsippany, New Jersey       41446
#
#          CIK      Founded
# 0      66740         1902
# 1      91142         1916
# 2       1800         1888
# 3    1551152  2013 (1888)
# 4    1467373         1989
# ..       ...          ...
# 498  1041061         1997
# 499   877212         1969
# 500  1136869         1927
# 501   109380         1873
# 502  1555280         1952
#
# [503 rows x 8 columns]

# %% [markdown]
# We can subset our ticker data set using standard indexing techniques. A good reference for this type of data manipulation is Panda's [Documentation](https://pandas.pydata.org/docs/user_guide/indexing.html#indexing-and-selecting-data) and [Cookbook](https://pandas.pydata.org/docs/user_guide/cookbook.html#cookbook-selection).

# %%
idx_tech = tickers['GICS Sector'] == 'Information Technology'
tech_sector = tickers[idx_tech]
tech_sector['ticker'].to_list()
# Out:
# ['ACN',
#  'ADBE',
#  'AMD',
#  'AKAM',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AAPL',
#  'AMAT',
#  'ANET',
#  'ADSK',
#  'AVGO',
#  'CDNS',
#  'CDW',
#  'CSCO',
#  'CTSH',
#  'GLW',
#  'ENPH',
#  'EPAM',
#  'FFIV',
#  'FICO',
#  'FSLR',
#  'FTNT',
#  'IT',
#  'GEN',
#  'HPE',
#  'HPQ',
#  'IBM',
#  'INTC',
#  'INTU',
#  'JBL',
#  'JNPR',
#  'KEYS',
#  'KLAC',
#  'LRCX',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MPWR',
#  'MSI',
#  'NTAP',
#  'NVDA',
#  'NXPI',
#  'ON',
#  'ORCL',
#  'PANW',
#  'PTC',
#  'QRVO',
#  'QCOM',
#  'ROP',
#  'CRM',
#  'STX',
#  'NOW',
#  'SWKS',
#  'SNPS',
#  'TEL',
#  'TDY',
#  'TER',
#  'TXN',
#  'TRMB',
#  'TYL',
#  'VRSN',
#  'WDC',
#  'ZBRA']

# %% [markdown]
# From the subset data frame, select one column and convert to list.

# %%
tech_tickers = tech_sector['ticker'].to_list()
tech_tickers
# Out:
# ['ACN',
#  'ADBE',
#  'AMD',
#  'AKAM',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AAPL',
#  'AMAT',
#  'ANET',
#  'ADSK',
#  'AVGO',
#  'CDNS',
#  'CDW',
#  'CSCO',
#  'CTSH',
#  'GLW',
#  'ENPH',
#  'EPAM',
#  'FFIV',
#  'FICO',
#  'FSLR',
#  'FTNT',
#  'IT',
#  'GEN',
#  'HPE',
#  'HPQ',
#  'IBM',
#  'INTC',
#  'INTU',
#  'JBL',
#  'JNPR',
#  'KEYS',
#  'KLAC',
#  'LRCX',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MPWR',
#  'MSI',
#  'NTAP',
#  'NVDA',
#  'NXPI',
#  'ON',
#  'ORCL',
#  'PANW',
#  'PTC',
#  'QRVO',
#  'QCOM',
#  'ROP',
#  'CRM',
#  'STX',
#  'NOW',
#  'SWKS',
#  'SNPS',
#  'TEL',
#  'TDY',
#  'TER',
#  'TXN',
#  'TRMB',
#  'TYL',
#  'VRSN',
#  'WDC',
#  'ZBRA']

# %%
tech_raw_dt = yf.download(tech_tickers, start = "2000-01-01", end = "2025-01-26")
# Out:
# [*********************100%***********************]  64 of 64 completed

# %% [markdown]
# The data that we downloaded combines several stocks and prices into a single row. We want to parse this arrangement into a dataframe that contains observations about a single stock on a given day per row. To do this, we can use the function [`stack()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.stack.html) and re-arrange the indices.

# %%
tech_raw_dt
# Out:
# Price                       Adj Close                                      \
# Ticker                           AAPL         ACN        ADBE         ADI
# Date
# 2000-01-03 00:00:00+00:00    0.843076         NaN   16.274668   28.095682
# 2000-01-04 00:00:00+00:00    0.771997         NaN   14.909398   26.674355
# 2000-01-05 00:00:00+00:00    0.783293         NaN   15.204174   27.063766
# 2000-01-06 00:00:00+00:00    0.715508         NaN   15.328291   26.323891
# 2000-01-07 00:00:00+00:00    0.749401         NaN   16.072987   27.063766
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00+00:00  229.979996  352.589996  429.989990  219.160004
# 2025-01-21 00:00:00+00:00  222.639999  356.420013  436.359985  221.449997
# 2025-01-22 00:00:00+00:00  223.830002  359.109985  437.320007  224.080002
# 2025-01-23 00:00:00+00:00  223.660004  363.260010  437.279999  228.350006
# 2025-01-24 00:00:00+00:00  222.779999  362.410004  435.380005  217.369995
#
# Price                                                                      \
# Ticker                           ADSK        AKAM        AMAT         AMD
# Date
# 2000-01-03 00:00:00+00:00    8.052903  321.250000   23.138018   15.500000
# 2000-01-04 00:00:00+00:00    7.660818  300.000000   21.994839   14.625000
# 2000-01-05 00:00:00+00:00    7.178245  283.500000   21.171738   15.000000
# 2000-01-06 00:00:00+00:00    6.740915  236.125000   21.206041   16.000000
# 2000-01-07 00:00:00+00:00    7.540173  248.375000   21.388948   16.250000
# ...                               ...         ...         ...         ...
# 2025-01-17 00:00:00+00:00  291.450012   91.010002  192.050003  121.459999
# 2025-01-21 00:00:00+00:00  296.910004   94.709999  192.869995  122.279999
# 2025-01-22 00:00:00+00:00  301.450012   95.110001  195.509995  123.750000
# 2025-01-23 00:00:00+00:00  301.079987   95.889999  190.699997  123.040001
# 2025-01-24 00:00:00+00:00  300.829987   97.699997  186.750000  122.839996
#
# Price                                              ...   Volume          \
# Ticker                           ANET        ANSS  ...     SWKS     TDY
# Date                                               ...
# 2000-01-03 00:00:00+00:00         NaN    2.765625  ...   512000  315400
# 2000-01-04 00:00:00+00:00         NaN    2.687500  ...   292600  444300
# 2000-01-05 00:00:00+00:00         NaN    2.703125  ...   411800  109100
# 2000-01-06 00:00:00+00:00         NaN    2.703125  ...   385400  120700
# 2000-01-07 00:00:00+00:00         NaN    2.703125  ...   536000  222100
# ...                               ...         ...  ...      ...     ...
# 2025-01-17 00:00:00+00:00  119.949997  349.929993  ...  2150600  264400
# 2025-01-21 00:00:00+00:00  121.500000  352.070007  ...  2389300  377400
# 2025-01-22 00:00:00+00:00  129.820007  356.630005  ...  2774100  668700
# 2025-01-23 00:00:00+00:00  129.119995  360.359985  ...  1777300  384700
# 2025-01-24 00:00:00+00:00  129.169998  357.369995  ...  1803300  333500
#
# Price                                                                     \
# Ticker                           TEL      TER     TRMB       TXN     TYL
# Date
# 2000-01-03 00:00:00+00:00        NaN  1353500  8025000  10815600  138300
# 2000-01-04 00:00:00+00:00        NaN  1611800  4963200   7952400  135100
# 2000-01-05 00:00:00+00:00        NaN  1855800  1930200  12142400  187200
# 2000-01-06 00:00:00+00:00        NaN   964700  2230800  11758400  107200
# 2000-01-07 00:00:00+00:00        NaN   809200  2166600  12938800   78900
# ...                              ...      ...      ...       ...     ...
# 2025-01-17 00:00:00+00:00  4102600.0  2253700  1010700   5407500  308000
# 2025-01-21 00:00:00+00:00  2568300.0  4083000  1341800   9621700  235400
# 2025-01-22 00:00:00+00:00  3162200.0  2262100  1098600   8222000  177300
# 2025-01-23 00:00:00+00:00  1417800.0  2214300  1210400  12694700  214000
# 2025-01-24 00:00:00+00:00  1017300.0  2254000   895300  15856600  155300
#
# Price
# Ticker                        VRSN      WDC     ZBRA
# Date
# 2000-01-03 00:00:00+00:00  2270100  2461900  1055700
# 2000-01-04 00:00:00+00:00  3002200  7660300   522450
# 2000-01-05 00:00:00+00:00  6886600  3944600   612225
# 2000-01-06 00:00:00+00:00  4003200  2468400   263925
# 2000-01-07 00:00:00+00:00  3803200  9783000   333900
# ...                            ...      ...      ...
# 2025-01-17 00:00:00+00:00   503300  7160500   270600
# 2025-01-21 00:00:00+00:00   781800  7045600   446000
# 2025-01-22 00:00:00+00:00   674500  9340500   497500
# 2025-01-23 00:00:00+00:00   630100  7059500   377100
# 2025-01-24 00:00:00+00:00   563300  6046500   258900
#
# [6304 rows x 384 columns]

# %%
# First, check what tech_raw_dt.stack() looks like.
tech_raw_dt.stack(future_stack=True).reset_index().sort_values(['Ticker','Date'])
# Out:
# Price                       Date Ticker   Adj Close       Close        High  \
# 0      2000-01-03 00:00:00+00:00   AAPL    0.843076    0.999442    1.004464
# 64     2000-01-04 00:00:00+00:00   AAPL    0.771997    0.915179    0.987723
# 128    2000-01-05 00:00:00+00:00   AAPL    0.783293    0.928571    0.987165
# 192    2000-01-06 00:00:00+00:00   AAPL    0.715508    0.848214    0.955357
# 256    2000-01-07 00:00:00+00:00   AAPL    0.749401    0.888393    0.901786
# ...                          ...    ...         ...         ...         ...
# 403199 2025-01-17 00:00:00+00:00   ZBRA  405.709991  405.709991  407.290009
# 403263 2025-01-21 00:00:00+00:00   ZBRA  418.070007  418.070007  419.850006
# 403327 2025-01-22 00:00:00+00:00   ZBRA  420.570007  420.570007  427.760010
# 403391 2025-01-23 00:00:00+00:00   ZBRA  421.109985  421.109985  422.290009
# 403455 2025-01-24 00:00:00+00:00   ZBRA  414.609985  414.609985  420.079987
#
# Price          Low        Open       Volume
# 0         0.907924    0.936384  535796800.0
# 64        0.903460    0.966518  512377600.0
# 128       0.919643    0.926339  778321600.0
# 192       0.848214    0.947545  767972800.0
# 256       0.852679    0.861607  460734400.0
# ...            ...         ...          ...
# 403199  402.290009  406.040009     270600.0
# 403263  407.619995  407.619995     446000.0
# 403327  419.589996  425.239990     497500.0
# 403391  414.450012  417.619995     377100.0
# 403455  413.739990  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %%
tech_dt = (tech_raw_dt
           .stack(future_stack=True)
           .reset_index()
           .sort_values(['Ticker', 'Date']))
tech_dt.columns.name = None
tech_dt
# Out:
#                             Date Ticker   Adj Close       Close        High  \
# 0      2000-01-03 00:00:00+00:00   AAPL    0.843076    0.999442    1.004464
# 64     2000-01-04 00:00:00+00:00   AAPL    0.771997    0.915179    0.987723
# 128    2000-01-05 00:00:00+00:00   AAPL    0.783293    0.928571    0.987165
# 192    2000-01-06 00:00:00+00:00   AAPL    0.715508    0.848214    0.955357
# 256    2000-01-07 00:00:00+00:00   AAPL    0.749401    0.888393    0.901786
# ...                          ...    ...         ...         ...         ...
# 403199 2025-01-17 00:00:00+00:00   ZBRA  405.709991  405.709991  407.290009
# 403263 2025-01-21 00:00:00+00:00   ZBRA  418.070007  418.070007  419.850006
# 403327 2025-01-22 00:00:00+00:00   ZBRA  420.570007  420.570007  427.760010
# 403391 2025-01-23 00:00:00+00:00   ZBRA  421.109985  421.109985  422.290009
# 403455 2025-01-24 00:00:00+00:00   ZBRA  414.609985  414.609985  420.079987
#
#                Low        Open       Volume
# 0         0.907924    0.936384  535796800.0
# 64        0.903460    0.966518  512377600.0
# 128       0.919643    0.926339  778321600.0
# 192       0.848214    0.947545  767972800.0
# 256       0.852679    0.861607  460734400.0
# ...            ...         ...          ...
# 403199  402.290009  406.040009     270600.0
# 403263  407.619995  407.619995     446000.0
# 403327  419.589996  425.239990     497500.0
# 403391  414.450012  417.619995     377100.0
# 403455  413.739990  419.059998     258900.0
#
# [403456 rows x 8 columns]

# %% [markdown]
# # Storing Data in CSV

# %% [markdown]
# + We have some data. How do we store it?
# + We can compare two options, CSV and Parqruet, by measuring their performance:
#
#     - Time to save.
#     - Space required.

# %%
def get_dir_size(path='.'):
    '''Returns the total size of files contained in path.'''
    total = 0
    with os.scandir(path) as it:
        for entry in it:
            if entry.is_file():
                total += entry.stat().st_size
            elif entry.is_dir():
                total += get_dir_size(entry.path)
    return total

# %%
import time

# %%
temp = os.getenv("TEMP_DATA")
os.makedirs(temp, exist_ok=True)
stock_path = os.path.join(temp, "stock_px.csv")

# %%
start = time.time()
tech_dt.to_csv(stock_path, index = False)
end = time.time()

print(f'Writing to dt ({tech_dt.shape})csv took {end - start} seconds.')
print(f'Csv file size { os.path.getsize(stock_path)*1e-6 } MB')
# Out:
# Writing to dt ((403456, 8))csv took 3.3565244674682617 seconds.
# Csv file size 47.817597 MB

# %% [markdown]
# ## Save Data to Parquet
#
# ### Dask
#
# We can work with with large data sets and parquet files. In fact, recent versions of pandas support pyarrow data types and future versions will require a pyarrow backend. The pyarrow library is an interface between Python and the Appache Arrow project. The [parquet data format](https://parquet.apache.org/) and [Arrow](https://arrow.apache.org/docs/python/parquet.html) are projects of the Apache Foundation.
#
# However, Dask is much more than an interface to Arrow: Dask provides parallel and distributed computing on pandas-like dataframes. It is also relatively easy to use, bridging a gap between pandas and Spark.

# %%
import dask.dataframe as dd
# Out:
# c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\_pyarrow_compat.py:15: FutureWarning: Minimal version of pyarrow will soon be increased to 14.0.1. You are using 11.0.0. Please consider upgrading.
#   warnings.warn(

# %%
px_dd = dd.from_pandas(tech_dt, npartitions = len(tech_tickers))
parquet_path = os.path.join(temp, "stock_px.parquet")

start = time.time()
px_dd.to_parquet(parquet_path, engine = "pyarrow")
end = time.time()

print(f'Writing dd ({tech_dt.shape}) to parquet took {end - start} seconds.')
print(f'Parquet file size { get_dir_size(parquet_path)*1e-6 } MB')
# Out:
# Writing dd ((403456, 8)) to parquet took 0.8066978454589844 seconds.
# Parquet file size 16.595398 MB

# %% [markdown]
# ### Parquet files and Dask Dataframes
#
# + Parquet files are immutable: once written, they cannot be modified.
# + Dask DataFrames are a useful implementation to manipulate data stored in parquets.
# + Parquet and Dask are not the same: parquet is a file format that can be accessed by many applications and programming languages (Python, R, PowerBI, etc.), while Dask is a package in Python to work with large datasets using distributed computation.
# + **Dask is not for everything** (see [Dask DataFrames Best Practices](https://docs.dask.org/en/stable/dataframe-best-practices.html)).
#
#     - Consider cases suchas small to large joins, where the small dataframe fits in memory, but the large one does not.
#     - If possible, use pandas: reduce, then use pandas.
#     - Pandas performance tips apply to Dask.
#     - Use the index: it is beneficial to have a well-defined index in Dask DataFrames, as it may speed up searching (filtering) the data. A one-dimensional index is allowed.
#     - Avoid (or minimize) full-data shuffling: indexing is an expensive operations.
#     - Some joins are more expensive than others.
#
#         * Not expensive:
#
#             - Join a Dask DataFrame with a pandas DataFrame.
#             - Join a Dask DataFrame with another Dask DataFrame of a single partition.
#             - Join Dask DataFrames along their indexes.
#
#         * Expensive:
#
#             - Join Dask DataFrames along columns that are not their index.

# %% [markdown]
# # How do we store prices?
#
# + We can store our data as a single blob. This can be difficult to maintain, especially because parquet files are immutable.
# + Strategy: organize data files by ticker and date. Update only latest month.

# %%
# CLean up before start
PRICE_DATA = os.getenv("PRICE_DATA")
import shutil
if os.path.exists(PRICE_DATA):
    shutil.rmtree(PRICE_DATA)

# %%
for ticker in tech_dt['Ticker'].unique():
    ticker_dt = tech_dt[tech_dt['Ticker'] == ticker]
    ticker_dt = ticker_dt.assign(Year = ticker_dt.Date.dt.year)
    for yr in ticker_dt['Year'].unique():
        yr_dd = dd.from_pandas(ticker_dt[ticker_dt['Year'] == yr],2)
        yr_path = os.path.join(PRICE_DATA, ticker, f"{ticker}_{yr}")
        os.makedirs(os.path.dirname(yr_path), exist_ok=True)
        yr_dd.to_parquet(yr_path, engine = "pyarrow")

# %% [markdown]
# Why would we want to store data this way?
#
# + Easier to maintain. We do not update old data, only recent data.
# + We can also access all files as follows.

# %% [markdown]
# # Load, Transform and Save

# %% [markdown]
# ## Load
#
# + Parquet files can be read individually or as a collection.
# + `dd.read_parquet()` can take a list (collection) of files as input.
# + Use `glob` to get the collection of files.

# %%
from glob import glob

parquet_files = glob(os.path.join(PRICE_DATA, "**/*.parquet"), recursive = True)
dd_px = dd.read_parquet(parquet_files).set_index("Ticker")

# %%
dd_px
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...
# Dask Name: setindex, 2 expressions
# Expr=SetIndex(frame=ReadParquetFSSpec(89dcb94), _other='Ticker', options={})

# %% [markdown]
# ## Transform
#
# + This transformation step will create a *Features* data set. In our case, features will be stock returns (we obtained prices).
# + Dask dataframes work like pandas dataframes: in particular, we can perform groupby and apply operations.
# + Notice the use of [an anonymous (lambda) function](https://realpython.com/python-lambda/) in the apply statement.

# %%
dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(
    lambda x: x.assign(Close_lag_1 = x['Close'].shift(1))
)
# Out:
# C:\Users\kaurp\AppData\Local\Temp\ipykernel_10868\3086392435.py:1: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   dd_shift = dd_px.groupby('Ticker', group_keys=False).apply(

# %%
dd_rets = dd_shift.assign(
    Returns = lambda x: x['Close']/x['Close_lag_1'] - 1
)

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(89dcb94), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x0000023AA97F1C10>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# ## Lazy Exection
#
# What does `dd_rets` contain?

# %%
dd_rets
# Out:
# Dask DataFrame Structure:
#                                Date Adj Close    Close     High      Low     Open   Volume   Year Close_lag_1  Returns
# npartitions=64
# AAPL            datetime64[ns, UTC]   float64  float64  float64  float64  float64  float64  int32     float64  float64
# ACN                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ...                             ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# ZBRA                            ...       ...      ...      ...      ...      ...      ...    ...         ...      ...
# Dask Name: assign, 9 expressions
# Expr=Assign(frame=Assign(frame=GroupByApply(frame=SetIndex(frame=ReadParquetFSSpec(89dcb94), _other='Ticker', options={}), observed=False, group_keys=False, func=<function <lambda> at 0x0000023AA97F1C10>, meta=<no_default>, args=(), kwargs={})))

# %% [markdown]
# + Dask is a lazy execution framework: commands will not execute until they are required.
# + To trigger an execution in dask use `.compute()`.

# %%
dd_rets.compute()
# Out:
#                             Date   Adj Close       Close        High  \
# Ticker
# AAPL   2000-01-03 00:00:00+00:00    0.843076    0.999442    1.004464
# AAPL   2000-01-04 00:00:00+00:00    0.771997    0.915179    0.987723
# AAPL   2000-01-05 00:00:00+00:00    0.783293    0.928571    0.987165
# AAPL   2000-01-06 00:00:00+00:00    0.715508    0.848214    0.955357
# AAPL   2000-01-07 00:00:00+00:00    0.749401    0.888393    0.901786
# ...                          ...         ...         ...         ...
# ZBRA   2025-01-17 00:00:00+00:00  405.709991  405.709991  407.290009
# ZBRA   2025-01-21 00:00:00+00:00  418.070007  418.070007  419.850006
# ZBRA   2025-01-22 00:00:00+00:00  420.570007  420.570007  427.760010
# ZBRA   2025-01-23 00:00:00+00:00  421.109985  421.109985  422.290009
# ZBRA   2025-01-24 00:00:00+00:00  414.609985  414.609985  420.079987
#
#                Low        Open       Volume  Year  Close_lag_1   Returns
# Ticker
# AAPL      0.907924    0.936384  535796800.0  2000          NaN       NaN
# AAPL      0.903460    0.966518  512377600.0  2000     0.999442 -0.084310
# AAPL      0.919643    0.926339  778321600.0  2000     0.915179  0.014633
# AAPL      0.848214    0.947545  767972800.0  2000     0.928571 -0.086538
# AAPL      0.852679    0.861607  460734400.0  2000     0.848214  0.047369
# ...            ...         ...          ...   ...          ...       ...
# ZBRA    402.290009  406.040009     270600.0  2025   402.720001  0.007424
# ZBRA    407.619995  407.619995     446000.0  2025   405.709991  0.030465
# ZBRA    419.589996  425.239990     497500.0  2025   418.070007  0.005980
# ZBRA    414.450012  417.619995     377100.0  2025   420.570007  0.001284
# ZBRA    413.739990  419.059998     258900.0  2025   421.109985 -0.015435
#
# [403456 rows x 10 columns]

# %% [markdown]
# ## Save
#
# + Apply transformations to calculate daily returns
# + Store the enriched data, the silver dataset, in a new directory.
# + Should we keep the same namespace? All columns?

# %%
# CLean up before save
FEATURES_DATA = os.getenv("FEATURES_DATA")
if os.path.exists(FEATURES_DATA):
    shutil.rmtree(FEATURES_DATA)
dd_rets.to_parquet(FEATURES_DATA, overwrite = True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[40], line 5
#       3 if os.path.exists(FEATURES_DATA):
#       4     shutil.rmtree(FEATURES_DATA)
# ----> 5 dd_rets.to_parquet(FEATURES_DATA, overwrite = True)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\_collection.py:3296, in DataFrame.to_parquet(self, path, **kwargs)
#    3293 def to_parquet(self, path, **kwargs):
#    3294     from dask_expr.io.parquet import to_parquet
# -> 3296     return to_parquet(self, path, **kwargs)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\io\parquet.py:653, in to_parquet(df, path, compression, write_index, append, overwrite, ignore_divisions, partition_on, storage_options, custom_metadata, write_metadata_file, compute, compute_kwargs, schema, name_function, filesystem, engine, **kwargs)
#     632     out = new_collection(
#     633         ToParquet(
#     634             df,
#    (...)
#     649         )
#     650     )
#     652 if compute:
# --> 653     out = out.compute(**compute_kwargs)
#     655 # Invalidate the filesystem listing cache for the output path after write.
#     656 # We do this before returning, even if `compute=False`. This helps ensure
#     657 # that reading files that were just written succeeds.
#     658 fs.invalidate_cache(path)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\_collection.py:477, in FrameBase.compute(self, fuse, **kwargs)
#     475     out = out.repartition(npartitions=1)
#     476 out = out.optimize(fuse=fuse)
# --> 477 return DaskMethodsMixin.compute(out, **kwargs)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:376, in DaskMethodsMixin.compute(self, **kwargs)
#     352 def compute(self, **kwargs):
#     353     """Compute this dask collection
#     354
#     355     This turns a lazy Dask collection into its in-memory equivalent.
#    (...)
#     374     dask.compute
#     375     """
# --> 376     (result,) = compute(self, traverse=False, **kwargs)
#     377     return result
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\base.py:662, in compute(traverse, optimize_graph, scheduler, get, *args, **kwargs)
#     659     postcomputes.append(x.__dask_postcompute__())
#     661 with shorten_traceback():
# --> 662     results = schedule(dsk, keys, **kwargs)
#     664 return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask_expr\_expr.py:3758, in Fused._execute_task(graph, name, *deps)
#    3756 for i, dep in enumerate(deps):
#    3757     graph["_" + str(i)] = dep
# -> 3758 return dask.core.get(graph, name)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:97, in ParquetFunctionWrapper.__call__(self, part)
#      94 if not isinstance(part, list):
#      95     part = [part]
# ---> 97 return read_parquet_part(
#      98     self.fs,
#      99     self.engine,
#     100     self.meta,
#     101     [
#     102         # Temporary workaround for HLG serialization bug
#     103         # (see: https://github.com/dask/dask/issues/8581)
#     104         (p.data["piece"], p.data.get("kwargs", {}))
#     105         if hasattr(p, "data")
#     106         else (p["piece"], p.get("kwargs", {}))
#     107         for p in part
#     108     ],
#     109     self.columns,
#     110     self.index,
#     111     self.common_kwargs,
#     112 )
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:645, in read_parquet_part(fs, engine, meta, part, columns, index, kwargs)
#     642 if len(part) == 1 or part[0][1] or not check_multi_support(engine):
#     643     # Part kwargs expected
#     644     func = engine.read_partition
# --> 645     dfs = [
#     646         func(
#     647             fs,
#     648             rg,
#     649             columns.copy(),
#     650             index,
#     651             **toolz.merge(kwargs, kw),
#     652         )
#     653         for (rg, kw) in part
#     654     ]
#     655     df = concat(dfs, axis=0) if len(dfs) > 1 else dfs[0]
#     656 else:
#     657     # No part specific kwargs, let engine read
#     658     # list of parts at once
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\core.py:646, in <listcomp>(.0)
#     642 if len(part) == 1 or part[0][1] or not check_multi_support(engine):
#     643     # Part kwargs expected
#     644     func = engine.read_partition
#     645     dfs = [
# --> 646         func(
#     647             fs,
#     648             rg,
#     649             columns.copy(),
#     650             index,
#     651             **toolz.merge(kwargs, kw),
#     652         )
#     653         for (rg, kw) in part
#     654     ]
#     655     df = concat(dfs, axis=0) if len(dfs) > 1 else dfs[0]
#     656 else:
#     657     # No part specific kwargs, let engine read
#     658     # list of parts at once
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:641, in ArrowDatasetEngine.read_partition(cls, fs, pieces, columns, index, dtype_backend, categories, partitions, filters, schema, **kwargs)
#     638     row_group = [row_group]
#     640 # Read in arrow table and convert to pandas
# --> 641 arrow_table = cls._read_table(
#     642     path_or_frag,
#     643     fs,
#     644     row_group,
#     645     columns,
#     646     schema,
#     647     filters,
#     648     partitions,
#     649     partition_keys,
#     650     **kwargs,
#     651 )
#     652 if multi_read:
#     653     tables.append(arrow_table)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:1774, in ArrowDatasetEngine._read_table(cls, path_or_frag, fs, row_groups, columns, schema, filters, partitions, partition_keys, **kwargs)
#    1767     arrow_table = frag.to_table(
#    1768         use_threads=False,
#    1769         schema=schema,
#    1770         columns=cols,
#    1771         filter=_filters_to_expression(filters) if filters else None,
#    1772     )
#    1773 else:
# -> 1774     arrow_table = _read_table_from_path(
#    1775         path_or_frag,
#    1776         fs,
#    1777         row_groups,
#    1778         columns,
#    1779         schema,
#    1780         filters,
#    1781         **kwargs,
#    1782     )
#    1784 # For pyarrow.dataset api, if we did not read directly from
#    1785 # fragments, we need to add the partitioned columns here.
#    1786 if partitions and isinstance(partitions, list):
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\parquet\arrow.py:257, in _read_table_from_path(path, fs, row_groups, columns, schema, filters, **kwargs)
#     254 pre_buffer_default = precache_options.get("method", None) is None
#     255 pre_buffer = {"pre_buffer": read_kwargs.pop("pre_buffer", pre_buffer_default)}
# --> 257 with _open_input_files(
#     258     [path],
#     259     fs=fs,
#     260     precache_options=precache_options,
#     261     **open_file_options,
#     262 )[0] as fil:
#     263     if row_groups == [None]:
#     264         return pq.ParquetFile(fil, **pre_buffer).read(
#     265             columns=columns,
#     266             use_threads=False,
#     267             use_pandas_metadata=True,
#     268             **read_kwargs,
#     269         )
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\utils.py:221, in _open_input_files(paths, fs, context_stack, open_file_func, precache_options, **kwargs)
#     208     return [
#     209         _set_context(
#     210             fsspec_parquet.open_parquet_file(
#    (...)
#     218         for path, rgs in zip(paths, row_groups)
#     219     ]
#     220 elif fs is not None:
# --> 221     return [_set_context(fs.open(path, **kwargs), context_stack) for path in paths]
#     222 return [_set_context(open(path, **kwargs), context_stack) for path in paths]
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\dask\dataframe\io\utils.py:221, in <listcomp>(.0)
#     208     return [
#     209         _set_context(
#     210             fsspec_parquet.open_parquet_file(
#    (...)
#     218         for path, rgs in zip(paths, row_groups)
#     219     ]
#     220 elif fs is not None:
# --> 221     return [_set_context(fs.open(path, **kwargs), context_stack) for path in paths]
#     222 return [_set_context(open(path, **kwargs), context_stack) for path in paths]
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\spec.py:1307, in AbstractFileSystem.open(self, path, mode, block_size, cache_options, compression, **kwargs)
#    1305 else:
#    1306     ac = kwargs.pop("autocommit", not self._intrans)
# -> 1307     f = self._open(
#    1308         path,
#    1309         mode=mode,
#    1310         block_size=block_size,
#    1311         autocommit=ac,
#    1312         cache_options=cache_options,
#    1313         **kwargs,
#    1314     )
#    1315     if compression is not None:
#    1316         from fsspec.compression import compr
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\implementations\local.py:180, in LocalFileSystem._open(self, path, mode, block_size, **kwargs)
#     178 if self.auto_mkdir and "w" in mode:
#     179     self.makedirs(self._parent(path), exist_ok=True)
# --> 180 return LocalFileOpener(path, mode, fs=self, **kwargs)
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\implementations\local.py:302, in LocalFileOpener.__init__(self, path, mode, autocommit, fs, compression, **kwargs)
#     300 self.compression = get_compression(path, compression)
#     301 self.blocksize = io.DEFAULT_BUFFER_SIZE
# --> 302 self._open()
#
# File c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\fsspec\implementations\local.py:307, in LocalFileOpener._open(self)
#     305 if self.f is None or self.f.closed:
#     306     if self.autocommit or "w" not in self.mode:
# --> 307         self.f = open(self.path, mode=self.mode)
#     308         if self.compression:
#     309             compress = compr[self.compression]
#
# FileNotFoundError: [Errno 2] No such file or directory: 'c:/Users/kaurp/production/05_src/data/prices/ANSS/ANSS_2025/part.1.parquet'

# %% [markdown]
# # Optional: from Jupyter to Command Line
#
# + We have drafted our code in a Jupyter Notebook.
# + Finalized code should be written in Python modules.
#
# ## Object Oriented vs Functional Programming
#
# + We can use classes to keep parameters and functions together.
# + We *could* use Object Oriented Programming, but parallelization of data manipulation and modelling tasks benefit from *Functional Programming*.
# + An Idea:
#
#     - [Data Oriented Programming](https://blog.klipse.tech/dop/2022/06/22/principles-of-dop.html).
#     - Use the class to bundle together parameters and functions.
#     - Use stateless operations and treat all data objects as immutable (we do not modify them, we overwrite them).
#     - Take advantage of [`@staticmethod`](https://realpython.com/instance-class-and-static-methods-demystified/).
#
# The code is in `./05_src/`.

# %% [markdown]
# Our original design was:
#
# ![](./images/02_target_pipeline_manager.png)

# %% [markdown]
# The `DataManager` class in `./05_src/data_manager.py` is a simple implementation of the ideas and code discussed in this notebook. The lines below will download data for about 500 stocks from the S&P500. Using this data a few features will be created and stored in the features data set.
#
# First, instantiate an object of class `DataManager`.

# %%
from data_manager import DataManager
dm = DataManager()

# %% [markdown]
# Download all prices.

# %%
dm.download_all()
# Out:
# 2025-01-29 23:58:56,027, data_manager.py, 42, INFO, Getting price data for all tickers.
# 2025-01-29 23:58:56,027, data_manager.py, 51, INFO, Getting tickers from ../../05_src/data/tickers/sp500_wiki.csv
# 2025-01-29 23:58:56,054, data_manager.py, 57, INFO, Processing all tickers
# 2025-01-29 23:58:56,056, data_manager.py, 70, INFO, Processing ticker ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS']
# 2025-01-29 23:58:56,058, data_manager.py, 100, INFO, Getting stock price data for ['MMM', 'AOS', 'ABT', 'ABBV', 'ACN', 'ADBE', 'AMD', 'AES', 'AFL', 'A', 'APD', 'ABNB', 'AKAM', 'ALB', 'ARE', 'ALGN', 'ALLE', 'LNT', 'ALL', 'GOOGL', 'GOOG', 'MO', 'AMZN', 'AMCR', 'AEE', 'AAL', 'AEP', 'AXP', 'AIG', 'AMT', 'AWK', 'AMP', 'AME', 'AMGN', 'APH', 'ADI', 'ANSS', 'AON', 'APA', 'AAPL', 'AMAT', 'APTV', 'ACGL', 'ADM', 'ANET', 'AJG', 'AIZ', 'T', 'ATO', 'ADSK', 'ADP', 'AZO', 'AVB', 'AVY', 'AXON', 'BKR', 'BALL', 'BAC', 'BK', 'BBWI', 'BAX', 'BDX', 'BRK.B', 'BBY', 'BIO', 'TECH', 'BIIB', 'BLK', 'BX', 'BA', 'BKNG', 'BWA', 'BXP', 'BSX', 'BMY', 'AVGO', 'BR', 'BRO', 'BF.B', 'BLDR', 'BG', 'CDNS', 'CZR', 'CPT', 'CPB', 'COF', 'CAH', 'KMX', 'CCL', 'CARR', 'CTLT', 'CAT', 'CBOE', 'CBRE', 'CDW', 'CE', 'COR', 'CNC', 'CNP', 'CF', 'CHRW', 'CRL', 'SCHW', 'CHTR', 'CVX', 'CMG', 'CB', 'CHD', 'CI', 'CINF', 'CTAS', 'CSCO', 'C', 'CFG', 'CLX', 'CME', 'CMS', 'KO', 'CTSH', 'CL', 'CMCSA', 'CMA', 'CAG', 'COP', 'ED', 'STZ', 'CEG', 'COO', 'CPRT', 'GLW', 'CTVA', 'CSGP', 'COST', 'CTRA', 'CCI', 'CSX', 'CMI', 'CVS', 'DHR', 'DRI', 'DVA', 'DAY', 'DE', 'DAL', 'XRAY', 'DVN', 'DXCM', 'FANG', 'DLR', 'DFS', 'DG', 'DLTR', 'D', 'DPZ', 'DOV', 'DOW', 'DHI', 'DTE', 'DUK', 'DD', 'EMN', 'ETN', 'EBAY', 'ECL', 'EIX', 'EW', 'EA', 'ELV', 'LLY', 'EMR', 'ENPH', 'ETR', 'EOG', 'EPAM', 'EQT', 'EFX', 'EQIX', 'EQR', 'ESS', 'EL', 'ETSY', 'EG', 'EVRG', 'ES', 'EXC', 'EXPE', 'EXPD', 'EXR', 'XOM', 'FFIV', 'FDS', 'FICO', 'FAST', 'FRT', 'FDX', 'FIS', 'FITB', 'FSLR', 'FE', 'FI', 'FLT', 'FMC', 'F', 'FTNT', 'FTV', 'FOXA', 'FOX', 'BEN', 'FCX', 'GRMN', 'IT', 'GEHC', 'GEN', 'GNRC', 'GD', 'GE', 'GIS', 'GM', 'GPC', 'GILD', 'GPN', 'GL', 'GS', 'HAL', 'HIG', 'HAS', 'HCA', 'PEAK', 'HSIC', 'HSY', 'HES', 'HPE', 'HLT', 'HOLX', 'HD', 'HON', 'HRL', 'HST', 'HWM', 'HPQ', 'HUBB', 'HUM', 'HBAN', 'HII', 'IBM', 'IEX', 'IDXX', 'ITW', 'ILMN', 'INCY', 'IR', 'PODD', 'INTC', 'ICE', 'IFF', 'IP', 'IPG', 'INTU', 'ISRG', 'IVZ', 'INVH', 'IQV', 'IRM', 'JBHT', 'JBL', 'JKHY', 'J', 'JNJ', 'JCI', 'JPM', 'JNPR', 'K', 'KVUE', 'KDP', 'KEY', 'KEYS', 'KMB', 'KIM', 'KMI', 'KLAC', 'KHC', 'KR', 'LHX', 'LH', 'LRCX', 'LW', 'LVS', 'LDOS', 'LEN', 'LIN', 'LYV', 'LKQ', 'LMT', 'L', 'LOW', 'LULU', 'LYB', 'MTB', 'MRO', 'MPC', 'MKTX', 'MAR', 'MMC', 'MLM', 'MAS', 'MA', 'MTCH', 'MKC', 'MCD', 'MCK', 'MDT', 'MRK', 'META', 'MET', 'MTD', 'MGM', 'MCHP', 'MU', 'MSFT', 'MAA', 'MRNA', 'MHK', 'MOH', 'TAP', 'MDLZ', 'MPWR', 'MNST', 'MCO', 'MS', 'MOS', 'MSI', 'MSCI', 'NDAQ', 'NTAP', 'NFLX', 'NEM', 'NWSA', 'NWS', 'NEE', 'NKE', 'NI', 'NDSN', 'NSC', 'NTRS', 'NOC', 'NCLH', 'NRG', 'NUE', 'NVDA', 'NVR', 'NXPI', 'ORLY', 'OXY', 'ODFL', 'OMC', 'ON', 'OKE', 'ORCL', 'OTIS', 'PCAR', 'PKG', 'PANW', 'PARA', 'PH', 'PAYX', 'PAYC', 'PYPL', 'PNR', 'PEP', 'PFE', 'PCG', 'PM', 'PSX', 'PNW', 'PXD', 'PNC', 'POOL', 'PPG', 'PPL', 'PFG', 'PG', 'PGR', 'PLD', 'PRU', 'PEG', 'PTC', 'PSA', 'PHM', 'QRVO', 'PWR', 'QCOM', 'DGX', 'RL', 'RJF', 'RTX', 'O', 'REG', 'REGN', 'RF', 'RSG', 'RMD', 'RVTY', 'RHI', 'ROK', 'ROL', 'ROP', 'ROST', 'RCL', 'SPGI', 'CRM', 'SBAC', 'SLB', 'STX', 'SRE', 'NOW', 'SHW', 'SPG', 'SWKS', 'SJM', 'SNA', 'SO', 'LUV', 'SWK', 'SBUX', 'STT', 'STLD', 'STE', 'SYK', 'SYF', 'SNPS', 'SYY', 'TMUS', 'TROW', 'TTWO', 'TPR', 'TRGP', 'TGT', 'TEL', 'TDY', 'TFX', 'TER', 'TSLA', 'TXN', 'TXT', 'TMO', 'TJX', 'TSCO', 'TT', 'TDG', 'TRV', 'TRMB', 'TFC', 'TYL', 'TSN', 'USB', 'UBER', 'UDR', 'ULTA', 'UNP', 'UAL', 'UPS', 'URI', 'UNH', 'UHS', 'VLO', 'VTR', 'VLTO', 'VRSN', 'VRSK', 'VZ', 'VRTX', 'VFC', 'VTRS', 'VICI', 'V', 'VMC', 'WRB', 'WAB', 'WBA', 'WMT', 'DIS', 'WBD', 'WM', 'WAT', 'WEC', 'WFC', 'WELL', 'WST', 'WDC', 'WRK', 'WY', 'WHR', 'WMB', 'WTW', 'GWW', 'WYNN', 'XEL', 'XYL', 'YUM', 'ZBRA', 'ZBH', 'ZION', 'ZTS'] from 2000-01-01 to 2025-01-29
# [*********************100%***********************]  503 of 503 completed
#
# 7 Failed downloads:
# ['PXD', 'FLT', 'PEAK', 'MRO', 'BRK.B', 'WRK']: YFTzMissingError('$%ticker%: possibly delisted; no timezone found')
# ['BF.B']: YFPricesMissingError('$%ticker%: possibly delisted; no price data found  (1d 2000-01-01 -> 2025-01-29)')
# 2025-01-29 23:59:36,173, data_manager.py, 80, INFO, Saving data by year
# 2025-01-29 23:59:36,390, data_manager.py, 83, INFO, Saving data for A
# 2025-01-29 23:59:36,953, data_manager.py, 83, INFO, Saving data for AAL
# 2025-01-29 23:59:37,477, data_manager.py, 83, INFO, Saving data for AAPL
# 2025-01-29 23:59:37,983, data_manager.py, 83, INFO, Saving data for ABBV
# 2025-01-29 23:59:38,469, data_manager.py, 83, INFO, Saving data for ABNB
# 2025-01-29 23:59:38,919, data_manager.py, 83, INFO, Saving data for ABT
# 2025-01-29 23:59:39,400, data_manager.py, 83, INFO, Saving data for ACGL
# 2025-01-29 23:59:39,900, data_manager.py, 83, INFO, Saving data for ACN
# 2025-01-29 23:59:40,405, data_manager.py, 83, INFO, Saving data for ADBE
# 2025-01-29 23:59:40,917, data_manager.py, 83, INFO, Saving data for ADI
# 2025-01-29 23:59:41,469, data_manager.py, 83, INFO, Saving data for ADM
# 2025-01-29 23:59:41,945, data_manager.py, 83, INFO, Saving data for ADP
# 2025-01-29 23:59:42,419, data_manager.py, 83, INFO, Saving data for ADSK
# 2025-01-29 23:59:42,922, data_manager.py, 83, INFO, Saving data for AEE
# 2025-01-29 23:59:43,385, data_manager.py, 83, INFO, Saving data for AEP
# 2025-01-29 23:59:43,849, data_manager.py, 83, INFO, Saving data for AES
# 2025-01-29 23:59:44,373, data_manager.py, 83, INFO, Saving data for AFL
# 2025-01-29 23:59:44,851, data_manager.py, 83, INFO, Saving data for AIG
# 2025-01-29 23:59:45,319, data_manager.py, 83, INFO, Saving data for AIZ
# 2025-01-29 23:59:45,784, data_manager.py, 83, INFO, Saving data for AJG
# 2025-01-29 23:59:46,254, data_manager.py, 83, INFO, Saving data for AKAM
# 2025-01-29 23:59:46,734, data_manager.py, 83, INFO, Saving data for ALB
# 2025-01-29 23:59:47,239, data_manager.py, 83, INFO, Saving data for ALGN
# 2025-01-29 23:59:47,720, data_manager.py, 83, INFO, Saving data for ALL
# 2025-01-29 23:59:48,189, data_manager.py, 83, INFO, Saving data for ALLE
# 2025-01-29 23:59:48,705, data_manager.py, 83, INFO, Saving data for AMAT
# 2025-01-29 23:59:49,235, data_manager.py, 83, INFO, Saving data for AMCR
# 2025-01-29 23:59:49,746, data_manager.py, 83, INFO, Saving data for AMD
# 2025-01-29 23:59:50,259, data_manager.py, 83, INFO, Saving data for AME
# 2025-01-29 23:59:50,734, data_manager.py, 83, INFO, Saving data for AMGN
# 2025-01-29 23:59:51,183, data_manager.py, 83, INFO, Saving data for AMP
# 2025-01-29 23:59:51,631, data_manager.py, 83, INFO, Saving data for AMT
# 2025-01-29 23:59:52,081, data_manager.py, 83, INFO, Saving data for AMZN
# 2025-01-29 23:59:52,498, data_manager.py, 83, INFO, Saving data for ANET
# 2025-01-29 23:59:52,967, data_manager.py, 83, INFO, Saving data for ANSS
# 2025-01-29 23:59:53,415, data_manager.py, 83, INFO, Saving data for AON
# 2025-01-29 23:59:53,866, data_manager.py, 83, INFO, Saving data for AOS
# 2025-01-29 23:59:54,314, data_manager.py, 83, INFO, Saving data for APA
# 2025-01-29 23:59:54,744, data_manager.py, 83, INFO, Saving data for APD
# 2025-01-29 23:59:55,169, data_manager.py, 83, INFO, Saving data for APH
# 2025-01-29 23:59:55,614, data_manager.py, 83, INFO, Saving data for APTV
# 2025-01-29 23:59:56,053, data_manager.py, 83, INFO, Saving data for ARE
# 2025-01-29 23:59:56,482, data_manager.py, 83, INFO, Saving data for ATO
# 2025-01-29 23:59:56,916, data_manager.py, 83, INFO, Saving data for AVB
# 2025-01-29 23:59:57,349, data_manager.py, 83, INFO, Saving data for AVGO
# 2025-01-29 23:59:57,796, data_manager.py, 83, INFO, Saving data for AVY
# 2025-01-29 23:59:58,230, data_manager.py, 83, INFO, Saving data for AWK
# 2025-01-29 23:59:58,646, data_manager.py, 83, INFO, Saving data for AXON
# 2025-01-29 23:59:59,079, data_manager.py, 83, INFO, Saving data for AXP
# 2025-01-29 23:59:59,512, data_manager.py, 83, INFO, Saving data for AZO
# 2025-01-29 23:59:59,946, data_manager.py, 83, INFO, Saving data for BA
# 2025-01-30 00:00:00,379, data_manager.py, 83, INFO, Saving data for BAC
# 2025-01-30 00:00:00,837, data_manager.py, 83, INFO, Saving data for BALL
# 2025-01-30 00:00:01,262, data_manager.py, 83, INFO, Saving data for BAX
# 2025-01-30 00:00:01,731, data_manager.py, 83, INFO, Saving data for BBWI
# 2025-01-30 00:00:02,168, data_manager.py, 83, INFO, Saving data for BBY
# 2025-01-30 00:00:02,612, data_manager.py, 83, INFO, Saving data for BDX
# 2025-01-30 00:00:03,045, data_manager.py, 83, INFO, Saving data for BEN
# 2025-01-30 00:00:03,481, data_manager.py, 83, INFO, Saving data for BF.B
# 2025-01-30 00:00:03,894, data_manager.py, 83, INFO, Saving data for BG
# 2025-01-30 00:00:04,344, data_manager.py, 83, INFO, Saving data for BIIB
# 2025-01-30 00:00:04,761, data_manager.py, 83, INFO, Saving data for BIO
# 2025-01-30 00:00:05,230, data_manager.py, 83, INFO, Saving data for BK
# 2025-01-30 00:00:05,683, data_manager.py, 83, INFO, Saving data for BKNG
# 2025-01-30 00:00:06,110, data_manager.py, 83, INFO, Saving data for BKR
# 2025-01-30 00:00:06,544, data_manager.py, 83, INFO, Saving data for BLDR
# 2025-01-30 00:00:06,993, data_manager.py, 83, INFO, Saving data for BLK
# 2025-01-30 00:00:07,426, data_manager.py, 83, INFO, Saving data for BMY
# 2025-01-30 00:00:07,860, data_manager.py, 83, INFO, Saving data for BR
# 2025-01-30 00:00:08,293, data_manager.py, 83, INFO, Saving data for BRK.B
# 2025-01-30 00:00:08,726, data_manager.py, 83, INFO, Saving data for BRO
# 2025-01-30 00:00:09,160, data_manager.py, 83, INFO, Saving data for BSX
# 2025-01-30 00:00:09,609, data_manager.py, 83, INFO, Saving data for BWA
# 2025-01-30 00:00:10,042, data_manager.py, 83, INFO, Saving data for BX
# 2025-01-30 00:00:10,509, data_manager.py, 83, INFO, Saving data for BXP
# 2025-01-30 00:00:10,942, data_manager.py, 83, INFO, Saving data for C
# 2025-01-30 00:00:11,392, data_manager.py, 83, INFO, Saving data for CAG
# 2025-01-30 00:00:11,827, data_manager.py, 83, INFO, Saving data for CAH
# 2025-01-30 00:00:12,275, data_manager.py, 83, INFO, Saving data for CARR
# 2025-01-30 00:00:12,760, data_manager.py, 83, INFO, Saving data for CAT
# 2025-01-30 00:00:13,241, data_manager.py, 83, INFO, Saving data for CB
# 2025-01-30 00:00:13,727, data_manager.py, 83, INFO, Saving data for CBOE
# 2025-01-30 00:00:14,280, data_manager.py, 83, INFO, Saving data for CBRE
# 2025-01-30 00:00:14,741, data_manager.py, 83, INFO, Saving data for CCI
# 2025-01-30 00:00:15,191, data_manager.py, 83, INFO, Saving data for CCL
# 2025-01-30 00:00:15,707, data_manager.py, 83, INFO, Saving data for CDNS
# 2025-01-30 00:00:16,236, data_manager.py, 83, INFO, Saving data for CDW
# 2025-01-30 00:00:16,858, data_manager.py, 83, INFO, Saving data for CE
# 2025-01-30 00:00:17,342, data_manager.py, 83, INFO, Saving data for CEG
# 2025-01-30 00:00:17,788, data_manager.py, 83, INFO, Saving data for CF
# 2025-01-30 00:00:18,237, data_manager.py, 83, INFO, Saving data for CFG
# 2025-01-30 00:00:18,672, data_manager.py, 83, INFO, Saving data for CHD
# 2025-01-30 00:00:19,188, data_manager.py, 83, INFO, Saving data for CHRW
# 2025-01-30 00:00:19,671, data_manager.py, 83, INFO, Saving data for CHTR
# 2025-01-30 00:00:20,154, data_manager.py, 83, INFO, Saving data for CI
# 2025-01-30 00:00:20,637, data_manager.py, 83, INFO, Saving data for CINF
# 2025-01-30 00:00:21,105, data_manager.py, 83, INFO, Saving data for CL
# 2025-01-30 00:00:21,572, data_manager.py, 83, INFO, Saving data for CLX
# 2025-01-30 00:00:22,070, data_manager.py, 83, INFO, Saving data for CMA
# 2025-01-30 00:00:22,538, data_manager.py, 83, INFO, Saving data for CMCSA
# 2025-01-30 00:00:23,047, data_manager.py, 83, INFO, Saving data for CME
# 2025-01-30 00:00:23,543, data_manager.py, 83, INFO, Saving data for CMG
# 2025-01-30 00:00:24,078, data_manager.py, 83, INFO, Saving data for CMI
# 2025-01-30 00:00:24,544, data_manager.py, 83, INFO, Saving data for CMS
# 2025-01-30 00:00:25,066, data_manager.py, 83, INFO, Saving data for CNC
# 2025-01-30 00:00:25,602, data_manager.py, 83, INFO, Saving data for CNP
# 2025-01-30 00:00:26,052, data_manager.py, 83, INFO, Saving data for COF
# 2025-01-30 00:00:26,517, data_manager.py, 83, INFO, Saving data for COO
# 2025-01-30 00:00:27,039, data_manager.py, 83, INFO, Saving data for COP
# 2025-01-30 00:00:27,484, data_manager.py, 83, INFO, Saving data for COR
# 2025-01-30 00:00:27,934, data_manager.py, 83, INFO, Saving data for COST
# 2025-01-30 00:00:28,470, data_manager.py, 83, INFO, Saving data for CPB
# 2025-01-30 00:00:29,019, data_manager.py, 83, INFO, Saving data for CPRT
# 2025-01-30 00:00:29,570, data_manager.py, 83, INFO, Saving data for CPT
# 2025-01-30 00:00:30,052, data_manager.py, 83, INFO, Saving data for CRL
# 2025-01-30 00:00:30,623, data_manager.py, 83, INFO, Saving data for CRM
# 2025-01-30 00:00:31,140, data_manager.py, 83, INFO, Saving data for CSCO
# 2025-01-30 00:00:31,685, data_manager.py, 83, INFO, Saving data for CSGP
# 2025-01-30 00:00:32,171, data_manager.py, 83, INFO, Saving data for CSX
# 2025-01-30 00:00:32,665, data_manager.py, 83, INFO, Saving data for CTAS
# 2025-01-30 00:00:33,184, data_manager.py, 83, INFO, Saving data for CTLT
# 2025-01-30 00:00:33,656, data_manager.py, 83, INFO, Saving data for CTRA
# 2025-01-30 00:00:34,134, data_manager.py, 83, INFO, Saving data for CTSH
# 2025-01-30 00:00:34,655, data_manager.py, 83, INFO, Saving data for CTVA
# 2025-01-30 00:00:35,202, data_manager.py, 83, INFO, Saving data for CVS
# 2025-01-30 00:00:35,666, data_manager.py, 83, INFO, Saving data for CVX
# 2025-01-30 00:00:36,136, data_manager.py, 83, INFO, Saving data for CZR
# 2025-01-30 00:00:36,588, data_manager.py, 83, INFO, Saving data for D
# 2025-01-30 00:00:37,032, data_manager.py, 83, INFO, Saving data for DAL
# 2025-01-30 00:00:37,502, data_manager.py, 83, INFO, Saving data for DAY
# 2025-01-30 00:00:37,951, data_manager.py, 83, INFO, Saving data for DD
# 2025-01-30 00:00:38,397, data_manager.py, 83, INFO, Saving data for DE
# 2025-01-30 00:00:38,835, data_manager.py, 83, INFO, Saving data for DFS
# 2025-01-30 00:00:39,349, data_manager.py, 83, INFO, Saving data for DG
# 2025-01-30 00:00:39,799, data_manager.py, 83, INFO, Saving data for DGX
# 2025-01-30 00:00:40,247, data_manager.py, 83, INFO, Saving data for DHI
# 2025-01-30 00:00:40,665, data_manager.py, 83, INFO, Saving data for DHR
# 2025-01-30 00:00:41,116, data_manager.py, 83, INFO, Saving data for DIS
# 2025-01-30 00:00:41,539, data_manager.py, 83, INFO, Saving data for DLR
# 2025-01-30 00:00:41,985, data_manager.py, 83, INFO, Saving data for DLTR
# 2025-01-30 00:00:42,398, data_manager.py, 83, INFO, Saving data for DOV
# 2025-01-30 00:00:42,917, data_manager.py, 83, INFO, Saving data for DOW
# 2025-01-30 00:00:43,326, data_manager.py, 83, INFO, Saving data for DPZ
# 2025-01-30 00:00:43,750, data_manager.py, 83, INFO, Saving data for DRI
# 2025-01-30 00:00:44,183, data_manager.py, 83, INFO, Saving data for DTE
# 2025-01-30 00:00:44,614, data_manager.py, 83, INFO, Saving data for DUK
# 2025-01-30 00:00:45,047, data_manager.py, 83, INFO, Saving data for DVA
# 2025-01-30 00:00:45,487, data_manager.py, 83, INFO, Saving data for DVN
# 2025-01-30 00:00:45,913, data_manager.py, 83, INFO, Saving data for DXCM
# 2025-01-30 00:00:46,361, data_manager.py, 83, INFO, Saving data for EA
# 2025-01-30 00:00:46,781, data_manager.py, 83, INFO, Saving data for EBAY
# 2025-01-30 00:00:47,206, data_manager.py, 83, INFO, Saving data for ECL
# 2025-01-30 00:00:47,629, data_manager.py, 83, INFO, Saving data for ED
# 2025-01-30 00:00:48,072, data_manager.py, 83, INFO, Saving data for EFX
# 2025-01-30 00:00:48,495, data_manager.py, 83, INFO, Saving data for EG
# 2025-01-30 00:00:48,929, data_manager.py, 83, INFO, Saving data for EIX
# 2025-01-30 00:00:49,362, data_manager.py, 83, INFO, Saving data for EL
# 2025-01-30 00:00:49,798, data_manager.py, 83, INFO, Saving data for ELV
# 2025-01-30 00:00:50,255, data_manager.py, 83, INFO, Saving data for EMN
# 2025-01-30 00:00:50,697, data_manager.py, 83, INFO, Saving data for EMR
# 2025-01-30 00:00:51,119, data_manager.py, 83, INFO, Saving data for ENPH
# 2025-01-30 00:00:51,578, data_manager.py, 83, INFO, Saving data for EOG
# 2025-01-30 00:00:52,028, data_manager.py, 83, INFO, Saving data for EPAM
# 2025-01-30 00:00:52,532, data_manager.py, 83, INFO, Saving data for EQIX
# 2025-01-30 00:00:52,978, data_manager.py, 83, INFO, Saving data for EQR
# 2025-01-30 00:00:53,427, data_manager.py, 83, INFO, Saving data for EQT
# 2025-01-30 00:00:53,862, data_manager.py, 83, INFO, Saving data for ES
# 2025-01-30 00:00:54,310, data_manager.py, 83, INFO, Saving data for ESS
# 2025-01-30 00:00:54,749, data_manager.py, 83, INFO, Saving data for ETN
# 2025-01-30 00:00:55,184, data_manager.py, 83, INFO, Saving data for ETR
# 2025-01-30 00:00:55,617, data_manager.py, 83, INFO, Saving data for ETSY
# 2025-01-30 00:00:56,051, data_manager.py, 83, INFO, Saving data for EVRG
# 2025-01-30 00:00:56,481, data_manager.py, 83, INFO, Saving data for EW
# 2025-01-30 00:00:56,926, data_manager.py, 83, INFO, Saving data for EXC
# 2025-01-30 00:00:57,369, data_manager.py, 83, INFO, Saving data for EXPD
# 2025-01-30 00:00:57,818, data_manager.py, 83, INFO, Saving data for EXPE
# 2025-01-30 00:00:58,246, data_manager.py, 83, INFO, Saving data for EXR
# 2025-01-30 00:00:58,692, data_manager.py, 83, INFO, Saving data for F
# 2025-01-30 00:00:59,126, data_manager.py, 83, INFO, Saving data for FANG
# 2025-01-30 00:00:59,579, data_manager.py, 83, INFO, Saving data for FAST
# 2025-01-30 00:01:00,012, data_manager.py, 83, INFO, Saving data for FCX
# 2025-01-30 00:01:00,459, data_manager.py, 83, INFO, Saving data for FDS
# 2025-01-30 00:01:00,908, data_manager.py, 83, INFO, Saving data for FDX
# 2025-01-30 00:01:01,358, data_manager.py, 83, INFO, Saving data for FE
# 2025-01-30 00:01:01,780, data_manager.py, 83, INFO, Saving data for FFIV
# 2025-01-30 00:01:02,261, data_manager.py, 83, INFO, Saving data for FI
# 2025-01-30 00:01:02,724, data_manager.py, 83, INFO, Saving data for FICO
# 2025-01-30 00:01:03,180, data_manager.py, 83, INFO, Saving data for FIS
# 2025-01-30 00:01:03,610, data_manager.py, 83, INFO, Saving data for FITB
# 2025-01-30 00:01:04,074, data_manager.py, 83, INFO, Saving data for FLT
# 2025-01-30 00:01:04,493, data_manager.py, 83, INFO, Saving data for FMC
# 2025-01-30 00:01:04,923, data_manager.py, 83, INFO, Saving data for FOX
# 2025-01-30 00:01:05,366, data_manager.py, 83, INFO, Saving data for FOXA
# 2025-01-30 00:01:05,807, data_manager.py, 83, INFO, Saving data for FRT
# 2025-01-30 00:01:06,240, data_manager.py, 83, INFO, Saving data for FSLR
# 2025-01-30 00:01:06,690, data_manager.py, 83, INFO, Saving data for FTNT
# 2025-01-30 00:01:07,159, data_manager.py, 83, INFO, Saving data for FTV
# 2025-01-30 00:01:07,623, data_manager.py, 83, INFO, Saving data for GD
# 2025-01-30 00:01:08,072, data_manager.py, 83, INFO, Saving data for GE
# 2025-01-30 00:01:08,506, data_manager.py, 83, INFO, Saving data for GEHC
# 2025-01-30 00:01:08,927, data_manager.py, 83, INFO, Saving data for GEN
# 2025-01-30 00:01:09,385, data_manager.py, 83, INFO, Saving data for GILD
# 2025-01-30 00:01:09,813, data_manager.py, 83, INFO, Saving data for GIS
# 2025-01-30 00:01:10,238, data_manager.py, 83, INFO, Saving data for GL
# 2025-01-30 00:01:10,655, data_manager.py, 83, INFO, Saving data for GLW
# 2025-01-30 00:01:11,105, data_manager.py, 83, INFO, Saving data for GM
# 2025-01-30 00:01:11,532, data_manager.py, 83, INFO, Saving data for GNRC
# 2025-01-30 00:01:11,953, data_manager.py, 83, INFO, Saving data for GOOG
# 2025-01-30 00:01:12,371, data_manager.py, 83, INFO, Saving data for GOOGL
# 2025-01-30 00:01:12,837, data_manager.py, 83, INFO, Saving data for GPC
# 2025-01-30 00:01:13,254, data_manager.py, 83, INFO, Saving data for GPN
# 2025-01-30 00:01:13,690, data_manager.py, 83, INFO, Saving data for GRMN
# 2025-01-30 00:01:14,137, data_manager.py, 83, INFO, Saving data for GS
# 2025-01-30 00:01:14,556, data_manager.py, 83, INFO, Saving data for GWW
# 2025-01-30 00:01:14,992, data_manager.py, 83, INFO, Saving data for HAL
# 2025-01-30 00:01:15,428, data_manager.py, 83, INFO, Saving data for HAS
# 2025-01-30 00:01:15,853, data_manager.py, 83, INFO, Saving data for HBAN
# 2025-01-30 00:01:16,286, data_manager.py, 83, INFO, Saving data for HCA
# 2025-01-30 00:01:16,703, data_manager.py, 83, INFO, Saving data for HD
# 2025-01-30 00:01:17,136, data_manager.py, 83, INFO, Saving data for HES
# 2025-01-30 00:01:17,569, data_manager.py, 83, INFO, Saving data for HIG
# 2025-01-30 00:01:18,010, data_manager.py, 83, INFO, Saving data for HII
# 2025-01-30 00:01:18,426, data_manager.py, 83, INFO, Saving data for HLT
# 2025-01-30 00:01:18,867, data_manager.py, 83, INFO, Saving data for HOLX
# 2025-01-30 00:01:19,285, data_manager.py, 83, INFO, Saving data for HON
# 2025-01-30 00:01:19,718, data_manager.py, 83, INFO, Saving data for HPE
# 2025-01-30 00:01:20,170, data_manager.py, 83, INFO, Saving data for HPQ
# 2025-01-30 00:01:20,668, data_manager.py, 83, INFO, Saving data for HRL
# 2025-01-30 00:01:21,118, data_manager.py, 83, INFO, Saving data for HSIC
# 2025-01-30 00:01:21,600, data_manager.py, 83, INFO, Saving data for HST
# 2025-01-30 00:01:22,068, data_manager.py, 83, INFO, Saving data for HSY
# 2025-01-30 00:01:22,551, data_manager.py, 83, INFO, Saving data for HUBB
# 2025-01-30 00:01:23,032, data_manager.py, 83, INFO, Saving data for HUM
# 2025-01-30 00:01:23,567, data_manager.py, 83, INFO, Saving data for HWM
# 2025-01-30 00:01:24,035, data_manager.py, 83, INFO, Saving data for IBM
# 2025-01-30 00:01:24,533, data_manager.py, 83, INFO, Saving data for ICE
# 2025-01-30 00:01:25,005, data_manager.py, 83, INFO, Saving data for IDXX
# 2025-01-30 00:01:25,466, data_manager.py, 83, INFO, Saving data for IEX
# 2025-01-30 00:01:25,935, data_manager.py, 83, INFO, Saving data for IFF
# 2025-01-30 00:01:26,414, data_manager.py, 83, INFO, Saving data for ILMN
# 2025-01-30 00:01:26,866, data_manager.py, 83, INFO, Saving data for INCY
# 2025-01-30 00:01:27,366, data_manager.py, 83, INFO, Saving data for INTC
# 2025-01-30 00:01:27,854, data_manager.py, 83, INFO, Saving data for INTU
# 2025-01-30 00:01:28,333, data_manager.py, 83, INFO, Saving data for INVH
# 2025-01-30 00:01:28,799, data_manager.py, 83, INFO, Saving data for IP
# 2025-01-30 00:01:29,248, data_manager.py, 83, INFO, Saving data for IPG
# 2025-01-30 00:01:29,717, data_manager.py, 83, INFO, Saving data for IQV
# 2025-01-30 00:01:30,185, data_manager.py, 83, INFO, Saving data for IR
# 2025-01-30 00:01:30,648, data_manager.py, 83, INFO, Saving data for IRM
# 2025-01-30 00:01:31,101, data_manager.py, 83, INFO, Saving data for ISRG
# 2025-01-30 00:01:31,564, data_manager.py, 83, INFO, Saving data for IT
# 2025-01-30 00:01:32,047, data_manager.py, 83, INFO, Saving data for ITW
# 2025-01-30 00:01:32,521, data_manager.py, 83, INFO, Saving data for IVZ
# 2025-01-30 00:01:32,994, data_manager.py, 83, INFO, Saving data for J
# 2025-01-30 00:01:33,514, data_manager.py, 83, INFO, Saving data for JBHT
# 2025-01-30 00:01:34,006, data_manager.py, 83, INFO, Saving data for JBL
# 2025-01-30 00:01:34,496, data_manager.py, 83, INFO, Saving data for JCI
# 2025-01-30 00:01:34,949, data_manager.py, 83, INFO, Saving data for JKHY
# 2025-01-30 00:01:35,430, data_manager.py, 83, INFO, Saving data for JNJ
# 2025-01-30 00:01:35,915, data_manager.py, 83, INFO, Saving data for JNPR
# 2025-01-30 00:01:36,396, data_manager.py, 83, INFO, Saving data for JPM
# 2025-01-30 00:01:36,865, data_manager.py, 83, INFO, Saving data for K
# 2025-01-30 00:01:37,362, data_manager.py, 83, INFO, Saving data for KDP
# 2025-01-30 00:01:37,832, data_manager.py, 83, INFO, Saving data for KEY
# 2025-01-30 00:01:38,312, data_manager.py, 83, INFO, Saving data for KEYS
# 2025-01-30 00:01:38,795, data_manager.py, 83, INFO, Saving data for KHC
# 2025-01-30 00:01:39,278, data_manager.py, 83, INFO, Saving data for KIM
# 2025-01-30 00:01:39,745, data_manager.py, 83, INFO, Saving data for KLAC
# 2025-01-30 00:01:40,263, data_manager.py, 83, INFO, Saving data for KMB
# 2025-01-30 00:01:40,730, data_manager.py, 83, INFO, Saving data for KMI
# 2025-01-30 00:01:41,213, data_manager.py, 83, INFO, Saving data for KMX
# 2025-01-30 00:01:41,696, data_manager.py, 83, INFO, Saving data for KO
# 2025-01-30 00:01:42,179, data_manager.py, 83, INFO, Saving data for KR
# 2025-01-30 00:01:42,644, data_manager.py, 83, INFO, Saving data for KVUE
# 2025-01-30 00:01:43,110, data_manager.py, 83, INFO, Saving data for L
# 2025-01-30 00:01:43,577, data_manager.py, 83, INFO, Saving data for LDOS
# 2025-01-30 00:01:44,110, data_manager.py, 83, INFO, Saving data for LEN
# 2025-01-30 00:01:44,593, data_manager.py, 83, INFO, Saving data for LH
# 2025-01-30 00:01:45,077, data_manager.py, 83, INFO, Saving data for LHX
# 2025-01-30 00:01:45,559, data_manager.py, 83, INFO, Saving data for LIN
# 2025-01-30 00:01:46,043, data_manager.py, 83, INFO, Saving data for LKQ
# 2025-01-30 00:01:46,509, data_manager.py, 83, INFO, Saving data for LLY
# 2025-01-30 00:01:46,993, data_manager.py, 83, INFO, Saving data for LMT
# 2025-01-30 00:01:47,476, data_manager.py, 83, INFO, Saving data for LNT
# 2025-01-30 00:01:47,944, data_manager.py, 83, INFO, Saving data for LOW
# 2025-01-30 00:01:48,394, data_manager.py, 83, INFO, Saving data for LRCX
# 2025-01-30 00:01:48,892, data_manager.py, 83, INFO, Saving data for LULU
# 2025-01-30 00:01:49,392, data_manager.py, 83, INFO, Saving data for LUV
# 2025-01-30 00:01:49,842, data_manager.py, 83, INFO, Saving data for LVS
# 2025-01-30 00:01:50,310, data_manager.py, 83, INFO, Saving data for LW
# 2025-01-30 00:01:50,774, data_manager.py, 83, INFO, Saving data for LYB
# 2025-01-30 00:01:51,224, data_manager.py, 83, INFO, Saving data for LYV
# 2025-01-30 00:01:51,774, data_manager.py, 83, INFO, Saving data for MA
# 2025-01-30 00:01:52,258, data_manager.py, 83, INFO, Saving data for MAA
# 2025-01-30 00:01:52,724, data_manager.py, 83, INFO, Saving data for MAR
# 2025-01-30 00:01:53,190, data_manager.py, 83, INFO, Saving data for MAS
# 2025-01-30 00:01:53,659, data_manager.py, 83, INFO, Saving data for MCD
# 2025-01-30 00:01:54,124, data_manager.py, 83, INFO, Saving data for MCHP
# 2025-01-30 00:01:54,657, data_manager.py, 83, INFO, Saving data for MCK
# 2025-01-30 00:01:55,123, data_manager.py, 83, INFO, Saving data for MCO
# 2025-01-30 00:01:55,588, data_manager.py, 83, INFO, Saving data for MDLZ
# 2025-01-30 00:01:56,052, data_manager.py, 83, INFO, Saving data for MDT
# 2025-01-30 00:01:56,523, data_manager.py, 83, INFO, Saving data for MET
# 2025-01-30 00:01:56,989, data_manager.py, 83, INFO, Saving data for META
# 2025-01-30 00:01:57,472, data_manager.py, 83, INFO, Saving data for MGM
# 2025-01-30 00:01:57,932, data_manager.py, 83, INFO, Saving data for MHK
# 2025-01-30 00:01:58,407, data_manager.py, 83, INFO, Saving data for MKC
# 2025-01-30 00:01:58,856, data_manager.py, 83, INFO, Saving data for MKTX
# 2025-01-30 00:01:59,324, data_manager.py, 83, INFO, Saving data for MLM
# 2025-01-30 00:01:59,771, data_manager.py, 83, INFO, Saving data for MMC
# 2025-01-30 00:02:00,258, data_manager.py, 83, INFO, Saving data for MMM
# 2025-01-30 00:02:00,704, data_manager.py, 83, INFO, Saving data for MNST
# 2025-01-30 00:02:01,188, data_manager.py, 83, INFO, Saving data for MO
# 2025-01-30 00:02:01,659, data_manager.py, 83, INFO, Saving data for MOH
# 2025-01-30 00:02:02,121, data_manager.py, 83, INFO, Saving data for MOS
# 2025-01-30 00:02:02,570, data_manager.py, 83, INFO, Saving data for MPC
# 2025-01-30 00:02:03,037, data_manager.py, 83, INFO, Saving data for MPWR
# 2025-01-30 00:02:03,487, data_manager.py, 83, INFO, Saving data for MRK
# 2025-01-30 00:02:03,955, data_manager.py, 83, INFO, Saving data for MRNA
# 2025-01-30 00:02:04,403, data_manager.py, 83, INFO, Saving data for MRO
# 2025-01-30 00:02:04,888, data_manager.py, 83, INFO, Saving data for MS
# 2025-01-30 00:02:05,351, data_manager.py, 83, INFO, Saving data for MSCI
# 2025-01-30 00:02:05,803, data_manager.py, 83, INFO, Saving data for MSFT
# 2025-01-30 00:02:06,269, data_manager.py, 83, INFO, Saving data for MSI
# 2025-01-30 00:02:06,754, data_manager.py, 83, INFO, Saving data for MTB
# 2025-01-30 00:02:07,188, data_manager.py, 83, INFO, Saving data for MTCH
# 2025-01-30 00:02:07,635, data_manager.py, 83, INFO, Saving data for MTD
# 2025-01-30 00:02:08,085, data_manager.py, 83, INFO, Saving data for MU
# 2025-01-30 00:02:08,571, data_manager.py, 83, INFO, Saving data for NCLH
# 2025-01-30 00:02:09,004, data_manager.py, 83, INFO, Saving data for NDAQ
# 2025-01-30 00:02:09,452, data_manager.py, 83, INFO, Saving data for NDSN
# 2025-01-30 00:02:09,918, data_manager.py, 83, INFO, Saving data for NEE
# 2025-01-30 00:02:10,369, data_manager.py, 83, INFO, Saving data for NEM
# 2025-01-30 00:02:10,839, data_manager.py, 83, INFO, Saving data for NFLX
# 2025-01-30 00:02:11,303, data_manager.py, 83, INFO, Saving data for NI
# 2025-01-30 00:02:11,751, data_manager.py, 83, INFO, Saving data for NKE
# 2025-01-30 00:02:12,217, data_manager.py, 83, INFO, Saving data for NOC
# 2025-01-30 00:02:12,674, data_manager.py, 83, INFO, Saving data for NOW
# 2025-01-30 00:02:13,133, data_manager.py, 83, INFO, Saving data for NRG
# 2025-01-30 00:02:13,586, data_manager.py, 83, INFO, Saving data for NSC
# 2025-01-30 00:02:14,067, data_manager.py, 83, INFO, Saving data for NTAP
# 2025-01-30 00:02:14,536, data_manager.py, 83, INFO, Saving data for NTRS
# 2025-01-30 00:02:14,998, data_manager.py, 83, INFO, Saving data for NUE
# 2025-01-30 00:02:15,437, data_manager.py, 83, INFO, Saving data for NVDA
# 2025-01-30 00:02:15,966, data_manager.py, 83, INFO, Saving data for NVR
# 2025-01-30 00:02:16,416, data_manager.py, 83, INFO, Saving data for NWS
# 2025-01-30 00:02:16,868, data_manager.py, 83, INFO, Saving data for NWSA
# 2025-01-30 00:02:17,332, data_manager.py, 83, INFO, Saving data for NXPI
# 2025-01-30 00:02:17,798, data_manager.py, 83, INFO, Saving data for O
# 2025-01-30 00:02:18,235, data_manager.py, 83, INFO, Saving data for ODFL
# 2025-01-30 00:02:18,684, data_manager.py, 83, INFO, Saving data for OKE
# 2025-01-30 00:02:19,131, data_manager.py, 83, INFO, Saving data for OMC
# 2025-01-30 00:02:19,581, data_manager.py, 83, INFO, Saving data for ON
# 2025-01-30 00:02:20,031, data_manager.py, 83, INFO, Saving data for ORCL
# 2025-01-30 00:02:20,497, data_manager.py, 83, INFO, Saving data for ORLY
# 2025-01-30 00:02:20,931, data_manager.py, 83, INFO, Saving data for OTIS
# 2025-01-30 00:02:21,381, data_manager.py, 83, INFO, Saving data for OXY
# 2025-01-30 00:02:21,830, data_manager.py, 83, INFO, Saving data for PANW
# 2025-01-30 00:02:22,294, data_manager.py, 83, INFO, Saving data for PARA
# 2025-01-30 00:02:22,730, data_manager.py, 83, INFO, Saving data for PAYC
# 2025-01-30 00:02:23,181, data_manager.py, 83, INFO, Saving data for PAYX
# 2025-01-30 00:02:23,614, data_manager.py, 83, INFO, Saving data for PCAR
# 2025-01-30 00:02:24,079, data_manager.py, 83, INFO, Saving data for PCG
# 2025-01-30 00:02:24,513, data_manager.py, 83, INFO, Saving data for PEAK
# 2025-01-30 00:02:24,963, data_manager.py, 83, INFO, Saving data for PEG
# 2025-01-30 00:02:25,396, data_manager.py, 83, INFO, Saving data for PEP
# 2025-01-30 00:02:25,863, data_manager.py, 83, INFO, Saving data for PFE
# 2025-01-30 00:02:26,296, data_manager.py, 83, INFO, Saving data for PFG
# 2025-01-30 00:02:26,745, data_manager.py, 83, INFO, Saving data for PG
# 2025-01-30 00:02:27,195, data_manager.py, 83, INFO, Saving data for PGR
# 2025-01-30 00:02:27,694, data_manager.py, 83, INFO, Saving data for PH
# 2025-01-30 00:02:28,128, data_manager.py, 83, INFO, Saving data for PHM
# 2025-01-30 00:02:28,597, data_manager.py, 83, INFO, Saving data for PKG
# 2025-01-30 00:02:29,045, data_manager.py, 83, INFO, Saving data for PLD
# 2025-01-30 00:02:29,496, data_manager.py, 83, INFO, Saving data for PM
# 2025-01-30 00:02:29,944, data_manager.py, 83, INFO, Saving data for PNC
# 2025-01-30 00:02:30,397, data_manager.py, 83, INFO, Saving data for PNR
# 2025-01-30 00:02:30,846, data_manager.py, 83, INFO, Saving data for PNW
# 2025-01-30 00:02:31,309, data_manager.py, 83, INFO, Saving data for PODD
# 2025-01-30 00:02:31,744, data_manager.py, 83, INFO, Saving data for POOL
# 2025-01-30 00:02:32,198, data_manager.py, 83, INFO, Saving data for PPG
# 2025-01-30 00:02:32,660, data_manager.py, 83, INFO, Saving data for PPL
# 2025-01-30 00:02:33,110, data_manager.py, 83, INFO, Saving data for PRU
# 2025-01-30 00:02:33,560, data_manager.py, 83, INFO, Saving data for PSA
# 2025-01-30 00:02:34,010, data_manager.py, 83, INFO, Saving data for PSX
# 2025-01-30 00:02:34,443, data_manager.py, 83, INFO, Saving data for PTC
# 2025-01-30 00:02:34,926, data_manager.py, 83, INFO, Saving data for PWR
# 2025-01-30 00:02:35,359, data_manager.py, 83, INFO, Saving data for PXD
# 2025-01-30 00:02:35,876, data_manager.py, 83, INFO, Saving data for PYPL
# 2025-01-30 00:02:36,359, data_manager.py, 83, INFO, Saving data for QCOM
# 2025-01-30 00:02:36,842, data_manager.py, 83, INFO, Saving data for QRVO
# 2025-01-30 00:02:37,394, data_manager.py, 83, INFO, Saving data for RCL
# 2025-01-30 00:02:37,892, data_manager.py, 83, INFO, Saving data for REG
# 2025-01-30 00:02:38,341, data_manager.py, 83, INFO, Saving data for REGN
# 2025-01-30 00:02:38,794, data_manager.py, 83, INFO, Saving data for RF
# 2025-01-30 00:02:39,241, data_manager.py, 83, INFO, Saving data for RHI
# 2025-01-30 00:02:39,691, data_manager.py, 83, INFO, Saving data for RJF
# 2025-01-30 00:02:40,141, data_manager.py, 83, INFO, Saving data for RL
# 2025-01-30 00:02:40,591, data_manager.py, 83, INFO, Saving data for RMD
# 2025-01-30 00:02:41,041, data_manager.py, 83, INFO, Saving data for ROK
# 2025-01-30 00:02:41,491, data_manager.py, 83, INFO, Saving data for ROL
# 2025-01-30 00:02:41,940, data_manager.py, 83, INFO, Saving data for ROP
# 2025-01-30 00:02:42,407, data_manager.py, 83, INFO, Saving data for ROST
# 2025-01-30 00:02:42,840, data_manager.py, 83, INFO, Saving data for RSG
# 2025-01-30 00:02:43,290, data_manager.py, 83, INFO, Saving data for RTX
# 2025-01-30 00:02:43,773, data_manager.py, 83, INFO, Saving data for RVTY
# 2025-01-30 00:02:44,256, data_manager.py, 83, INFO, Saving data for SBAC
# 2025-01-30 00:02:44,723, data_manager.py, 83, INFO, Saving data for SBUX
# 2025-01-30 00:02:45,173, data_manager.py, 83, INFO, Saving data for SCHW
# 2025-01-30 00:02:45,622, data_manager.py, 83, INFO, Saving data for SHW
# 2025-01-30 00:02:46,056, data_manager.py, 83, INFO, Saving data for SJM
# 2025-01-30 00:02:46,500, data_manager.py, 83, INFO, Saving data for SLB
# 2025-01-30 00:02:46,943, data_manager.py, 83, INFO, Saving data for SNA
# 2025-01-30 00:02:47,388, data_manager.py, 83, INFO, Saving data for SNPS
# 2025-01-30 00:02:47,855, data_manager.py, 83, INFO, Saving data for SO
# 2025-01-30 00:02:48,279, data_manager.py, 83, INFO, Saving data for SPG
# 2025-01-30 00:02:48,721, data_manager.py, 83, INFO, Saving data for SPGI
# 2025-01-30 00:02:49,164, data_manager.py, 83, INFO, Saving data for SRE
# 2025-01-30 00:02:49,654, data_manager.py, 83, INFO, Saving data for STE
# 2025-01-30 00:02:50,104, data_manager.py, 83, INFO, Saving data for STLD
# 2025-01-30 00:02:50,540, data_manager.py, 83, INFO, Saving data for STT
# 2025-01-30 00:02:50,973, data_manager.py, 83, INFO, Saving data for STX
# 2025-01-30 00:02:51,437, data_manager.py, 83, INFO, Saving data for STZ
# 2025-01-30 00:02:51,870, data_manager.py, 83, INFO, Saving data for SWK
# 2025-01-30 00:02:52,303, data_manager.py, 83, INFO, Saving data for SWKS
# 2025-01-30 00:02:52,771, data_manager.py, 83, INFO, Saving data for SYF
# 2025-01-30 00:02:53,206, data_manager.py, 83, INFO, Saving data for SYK
# 2025-01-30 00:02:53,637, data_manager.py, 83, INFO, Saving data for SYY
# 2025-01-30 00:02:54,123, data_manager.py, 83, INFO, Saving data for T
# 2025-01-30 00:02:54,552, data_manager.py, 83, INFO, Saving data for TAP
# 2025-01-30 00:02:54,986, data_manager.py, 83, INFO, Saving data for TDG
# 2025-01-30 00:02:55,419, data_manager.py, 83, INFO, Saving data for TDY
# 2025-01-30 00:02:55,890, data_manager.py, 83, INFO, Saving data for TECH
# 2025-01-30 00:02:56,319, data_manager.py, 83, INFO, Saving data for TEL
# 2025-01-30 00:02:56,769, data_manager.py, 83, INFO, Saving data for TER
# 2025-01-30 00:02:57,236, data_manager.py, 83, INFO, Saving data for TFC
# 2025-01-30 00:02:57,668, data_manager.py, 83, INFO, Saving data for TFX
# 2025-01-30 00:02:58,101, data_manager.py, 83, INFO, Saving data for TGT
# 2025-01-30 00:02:58,553, data_manager.py, 83, INFO, Saving data for TJX
# 2025-01-30 00:02:58,985, data_manager.py, 83, INFO, Saving data for TMO
# 2025-01-30 00:02:59,441, data_manager.py, 83, INFO, Saving data for TMUS
# 2025-01-30 00:02:59,868, data_manager.py, 83, INFO, Saving data for TPR
# 2025-01-30 00:03:00,301, data_manager.py, 83, INFO, Saving data for TRGP
# 2025-01-30 00:03:00,743, data_manager.py, 83, INFO, Saving data for TRMB
# 2025-01-30 00:03:01,235, data_manager.py, 83, INFO, Saving data for TROW
# 2025-01-30 00:03:01,667, data_manager.py, 83, INFO, Saving data for TRV
# 2025-01-30 00:03:02,109, data_manager.py, 83, INFO, Saving data for TSCO
# 2025-01-30 00:03:02,569, data_manager.py, 83, INFO, Saving data for TSLA
# 2025-01-30 00:03:03,017, data_manager.py, 83, INFO, Saving data for TSN
# 2025-01-30 00:03:03,467, data_manager.py, 83, INFO, Saving data for TT
# 2025-01-30 00:03:03,916, data_manager.py, 83, INFO, Saving data for TTWO
# 2025-01-30 00:03:04,350, data_manager.py, 83, INFO, Saving data for TXN
# 2025-01-30 00:03:04,866, data_manager.py, 83, INFO, Saving data for TXT
# 2025-01-30 00:03:05,316, data_manager.py, 83, INFO, Saving data for TYL
# 2025-01-30 00:03:05,789, data_manager.py, 83, INFO, Saving data for UAL
# 2025-01-30 00:03:06,215, data_manager.py, 83, INFO, Saving data for UBER
# 2025-01-30 00:03:06,654, data_manager.py, 83, INFO, Saving data for UDR
# 2025-01-30 00:03:07,098, data_manager.py, 83, INFO, Saving data for UHS
# 2025-01-30 00:03:07,548, data_manager.py, 83, INFO, Saving data for ULTA
# 2025-01-30 00:03:07,996, data_manager.py, 83, INFO, Saving data for UNH
# 2025-01-30 00:03:08,431, data_manager.py, 83, INFO, Saving data for UNP
# 2025-01-30 00:03:08,868, data_manager.py, 83, INFO, Saving data for UPS
# 2025-01-30 00:03:09,334, data_manager.py, 83, INFO, Saving data for URI
# 2025-01-30 00:03:09,764, data_manager.py, 83, INFO, Saving data for USB
# 2025-01-30 00:03:10,214, data_manager.py, 83, INFO, Saving data for V
# 2025-01-30 00:03:10,663, data_manager.py, 83, INFO, Saving data for VFC
# 2025-01-30 00:03:11,097, data_manager.py, 83, INFO, Saving data for VICI
# 2025-01-30 00:03:11,534, data_manager.py, 83, INFO, Saving data for VLO
# 2025-01-30 00:03:12,034, data_manager.py, 83, INFO, Saving data for VLTO
# 2025-01-30 00:03:12,463, data_manager.py, 83, INFO, Saving data for VMC
# 2025-01-30 00:03:12,913, data_manager.py, 83, INFO, Saving data for VRSK
# 2025-01-30 00:03:13,362, data_manager.py, 83, INFO, Saving data for VRSN
# 2025-01-30 00:03:13,812, data_manager.py, 83, INFO, Saving data for VRTX
# 2025-01-30 00:03:14,262, data_manager.py, 83, INFO, Saving data for VTR
# 2025-01-30 00:03:14,698, data_manager.py, 83, INFO, Saving data for VTRS
# 2025-01-30 00:03:15,131, data_manager.py, 83, INFO, Saving data for VZ
# 2025-01-30 00:03:15,623, data_manager.py, 83, INFO, Saving data for WAB
# 2025-01-30 00:03:16,063, data_manager.py, 83, INFO, Saving data for WAT
# 2025-01-30 00:03:16,514, data_manager.py, 83, INFO, Saving data for WBA
# 2025-01-30 00:03:16,966, data_manager.py, 83, INFO, Saving data for WBD
# 2025-01-30 00:03:17,411, data_manager.py, 83, INFO, Saving data for WDC
# 2025-01-30 00:03:17,961, data_manager.py, 83, INFO, Saving data for WEC
# 2025-01-30 00:03:18,430, data_manager.py, 83, INFO, Saving data for WELL
# 2025-01-30 00:03:18,878, data_manager.py, 83, INFO, Saving data for WFC
# 2025-01-30 00:03:19,344, data_manager.py, 83, INFO, Saving data for WHR
# 2025-01-30 00:03:19,807, data_manager.py, 83, INFO, Saving data for WM
# 2025-01-30 00:03:20,294, data_manager.py, 83, INFO, Saving data for WMB
# 2025-01-30 00:03:20,751, data_manager.py, 83, INFO, Saving data for WMT
# 2025-01-30 00:03:21,227, data_manager.py, 83, INFO, Saving data for WRB
# 2025-01-30 00:03:21,677, data_manager.py, 83, INFO, Saving data for WRK
# 2025-01-30 00:03:22,126, data_manager.py, 83, INFO, Saving data for WST
# 2025-01-30 00:03:22,577, data_manager.py, 83, INFO, Saving data for WTW
# 2025-01-30 00:03:23,044, data_manager.py, 83, INFO, Saving data for WY
# 2025-01-30 00:03:23,503, data_manager.py, 83, INFO, Saving data for WYNN
# 2025-01-30 00:03:23,943, data_manager.py, 83, INFO, Saving data for XEL
# 2025-01-30 00:03:24,395, data_manager.py, 83, INFO, Saving data for XOM
# 2025-01-30 00:03:24,859, data_manager.py, 83, INFO, Saving data for XRAY
# 2025-01-30 00:03:25,309, data_manager.py, 83, INFO, Saving data for XYL
# 2025-01-30 00:03:25,759, data_manager.py, 83, INFO, Saving data for YUM
# 2025-01-30 00:03:26,209, data_manager.py, 83, INFO, Saving data for ZBH
# 2025-01-30 00:03:26,725, data_manager.py, 83, INFO, Saving data for ZBRA
# 2025-01-30 00:03:27,211, data_manager.py, 83, INFO, Saving data for ZION
# 2025-01-30 00:03:27,675, data_manager.py, 83, INFO, Saving data for ZTS

# %% [markdown]
# Finally, add features to the data set and save to a *feature store*.

# %%
dm.featurize()
# Out:
# 2025-01-30 00:03:43,187, data_manager.py, 114, INFO, Creating features data.
# 2025-01-30 00:03:43,189, data_manager.py, 124, INFO, Loading price data from ../../05_src/data/prices/
# 2025-01-30 00:03:45,652, data_manager.py, 133, INFO, Creating features
# c:\Users\kaurp\production\01_materials\labs\../../05_src\data_manager.py:136: UserWarning: `meta` is not specified, inferred from partial data. Please provide `meta` if the result is unexpected.
#   Before: .apply(func)
#   After:  .apply(func, meta={'x': 'f8', 'y': 'f8'}) for dataframe result
#   or:     .apply(func, meta=('x', 'f8'))            for series result
#   features = (price_dd.groupby('Ticker', group_keys=False)
# 2025-01-30 00:03:45,652, data_manager.py, 158, INFO, Saving features to ../../05_src/data/features/stock_features.parquet
# c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\pandas\core\frame.py:717: DeprecationWarning: Passing a BlockManager to DataFrame is deprecated and will raise in a future version. Use public APIs instead.
#   warnings.warn(
# c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:766: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:766: DeprecationWarning: DatetimeTZBlock is deprecated and will be removed in a future version. Use public APIs instead.
#   klass=_int.DatetimeTZBlock,
# c:\Users\kaurp\miniconda3\envs\dsi_participant\lib\site-packages\pyarrow\pandas_compat.py:456: DeprecationWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if _pandas_api.is_sparse(col):
